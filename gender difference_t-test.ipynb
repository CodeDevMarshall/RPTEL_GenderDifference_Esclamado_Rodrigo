# %%
import os
import glob
import pandas as pd
import pandasql
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Compare assessment outcomes between male and female learners
os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box=pd.read_csv("gender_analysis_all_behavior2.csv")

fig, ax = plt.subplots(figsize=(5, 6))
sns.boxplot(x='gender', y='score', data=df_box, orient='v' , ax=ax, showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Comparison of Assessment Outcomes')
# Out:
# [Text(0.5, 1.0, 'Comparison of Assessment Outcomes')]

# %%
# Compare in-game behaviors between male and female learners
os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box=pd.read_csv("gender_analysis_all_behavior2.csv")

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 18))


sns.boxplot(x='gender', y='time_spent', data=df_box, orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Time spent')
sns.boxplot(x='gender', y='idletime', data=df_box, orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Idle time')
sns.boxplot(x='gender', y='Distance', data=df_box, orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Distance Traveled')
sns.boxplot(x='gender', y='Area', data=df_box, orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Area Covered')

sns.boxplot(x='gender', y='slope_ave', data=df_box, orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Slope Average')
sns.boxplot(x='gender', y='observations', data=df_box, orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Number of Observations')
sns.boxplot(x='gender', y='M1task', data=df_box, orient='v' , ax=axes[2][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M1 Task Completion')
sns.boxplot(x='gender', y='M2task', data=df_box, orient='v' , ax=axes[2][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M2 Task Completion')
fig.delaxes(axes[2][2])

# %%
# Compare Change in SIQ between male and female learners
os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box_siq=pd.read_csv("gender_analysis_all_SIQ.csv")

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 12))

sns.boxplot(x='gender', y='Ave_SIQ', data=df_box_siq, orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Average SIQ')
sns.boxplot(x='gender', y='SE', data=df_box_siq, orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Self-Efficacy')
sns.boxplot(x='gender', y='IN', data=df_box_siq, orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Interest')

sns.boxplot(x='gender', y='CG', data=df_box_siq, orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Goals')
sns.boxplot(x='gender', y='CA', data=df_box_siq, orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Action')
sns.boxplot(x='gender', y='OE', data=df_box_siq, orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Catgeory: Outcome Expectation')
# Out:
# [Text(0.5, 1.0, 'SIQ Catgeory: Outcome Expectation')]

# %%
#Compare in-game behaviors of frustrated and not frustrated - all learners

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box=pd.read_csv("gender_analysis_all_behavior_fb.csv")

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 18))

sns.boxplot(x='frustration', y='time_spent', data=df_box, orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Time spent')
sns.boxplot(x='frustration', y='idle_time', data=df_box, orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Idle time')
sns.boxplot(x='frustration', y='Distance', data=df_box, orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Distance Traveled')

sns.boxplot(x='frustration', y='Area', data=df_box, orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Area Covered')
sns.boxplot(x='frustration', y='slope_ave', data=df_box, orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Slope Average')
sns.boxplot(x='frustration', y='observations', data=df_box, orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Number of Observations')

sns.boxplot(x='frustration', y='M1_task', data=df_box, orient='v' , ax=axes[2][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M1 Task Completion')
sns.boxplot(x='frustration', y='M2_task', data=df_box, orient='v' , ax=axes[2][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M2 Task Completion')
fig.delaxes(axes[2][2])

# %%
#Compare in-game behaviors of frustrated and not frustrated - Male vs Female

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box=pd.read_csv("gender_analysis_all_behavior_fb.csv")

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 20))

sns.boxplot(x='gender', y='time_spent', data=df_box, hue='frustration', orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Time spent')
sns.boxplot(x='gender', y='idle_time', data=df_box, hue='frustration', orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Idle time')
sns.boxplot(x='gender', y='Distance', data=df_box, hue='frustration', orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Distance Traveled')

sns.boxplot(x='gender', y='Area', data=df_box, hue='frustration', orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Area Covered')
sns.boxplot(x='gender', y='slope_ave', data=df_box, hue='frustration', orient='v' , ax=axes[2][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Slope Average')
sns.boxplot(x='gender', y='observations', data=df_box, hue='frustration', orient='v' , ax=axes[2][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Number of Observations')

sns.boxplot(x='gender', y='M1_task', data=df_box, hue='frustration', orient='v' , ax=axes[3][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M1 Task Completion')
sns.boxplot(x='gender', y='M2_task', data=df_box, hue='frustration', orient='v' , ax=axes[3][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M2 Task Completion')
# Out:
# [Text(0.5, 1.0, 'M2 Task Completion')]

# %%
#Compare in-game behaviors of bored and not bored - all learners

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box=pd.read_csv("gender_analysis_all_behavior_fb.csv")

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 18))


sns.boxplot(x='boredom', y='time_spent', data=df_box, orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Time spent')
sns.boxplot(x='boredom', y='idle_time', data=df_box, orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Idle time')
sns.boxplot(x='boredom', y='Distance', data=df_box, orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Distance Traveled')

sns.boxplot(x='boredom', y='Area', data=df_box, orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Area Covered')
sns.boxplot(x='boredom', y='slope_ave', data=df_box, orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Slope Average')
sns.boxplot(x='boredom', y='observations', data=df_box, orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Number of Observations')

sns.boxplot(x='boredom', y='M1_task', data=df_box, orient='v' , ax=axes[2][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M1 Task Completion')
sns.boxplot(x='boredom', y='M2_task', data=df_box, orient='v' , ax=axes[2][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M2 Task Completion')
fig.delaxes(axes[2][2])

# %%
#Compare in-game behaviors of bored and not bored - Male vs Female 

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box=pd.read_csv("gender_analysis_all_behavior_fb.csv")

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 20))


sns.boxplot(x='gender', y='time_spent', data=df_box, hue='boredom', orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Time spent')
sns.boxplot(x='gender', y='idle_time', data=df_box, hue='boredom', orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Idle time')
sns.boxplot(x='gender', y='Distance', data=df_box, hue='boredom', orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Distance Traveled')

sns.boxplot(x='gender', y='Area', data=df_box, hue='boredom', orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Area Covered')
sns.boxplot(x='gender', y='slope_ave', data=df_box, hue='boredom', orient='v' , ax=axes[2][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Slope Average')
sns.boxplot(x='gender', y='observations', data=df_box, hue='boredom', orient='v' , ax=axes[2][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Number of Observations')

sns.boxplot(x='gender', y='M1_task', data=df_box, hue='boredom', orient='v' , ax=axes[3][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M1 Task Completion')
sns.boxplot(x='gender', y='M2_task', data=df_box, hue='boredom', orient='v' , ax=axes[3][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='M2 Task Completion')
# Out:
# [Text(0.5, 1.0, 'M2 Task Completion')]

# %%
#Compare SIQ of frustrated and not frustrated - all learners

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box_siq=pd.read_csv("gender_analysis_all_SIQ_fb.csv")

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 12))

sns.boxplot(x='frustration', y='Ave_SIQ', data=df_box_siq, orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Average SIQ')
sns.boxplot(x='frustration', y='SE', data=df_box_siq, orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Self-Efficacy')
sns.boxplot(x='frustration', y='IN', data=df_box_siq, orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Interest')

sns.boxplot(x='frustration', y='CG', data=df_box_siq, orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Goals')
sns.boxplot(x='frustration', y='CA', data=df_box_siq, orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Action')
sns.boxplot(x='frustration', y='OE', data=df_box_siq, orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Catgeory: Outcome Expectation')
# Out:
# [Text(0.5, 1.0, 'SIQ Catgeory: Outcome Expectation')]

# %%
#Compare SIQ of frustrated and not frustrated - male vs female

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box_siq=pd.read_csv("gender_analysis_all_SIQ_fb.csv")

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 12))

sns.boxplot(x='gender', y='Ave_SIQ', data=df_box_siq, hue='frustration', orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Average SIQ')
sns.boxplot(x='gender', y='SE', data=df_box_siq, hue='frustration', orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Self-Efficacy')
sns.boxplot(x='gender', y='IN', data=df_box_siq, hue='frustration', orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Interest')

sns.boxplot(x='gender', y='CG', data=df_box_siq, hue='frustration', orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Goals')
sns.boxplot(x='gender', y='CA', data=df_box_siq, hue='frustration', orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Action')
sns.boxplot(x='gender', y='OE', data=df_box_siq, hue='frustration', orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Catgeory: Outcome Expectation')
# Out:
# [Text(0.5, 1.0, 'SIQ Catgeory: Outcome Expectation')]

# %%
#Compare SIQ of bored and not bored - all learners

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box_siq=pd.read_csv("gender_analysis_all_SIQ_fb.csv")

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 12))

sns.boxplot(x='boredom', y='Ave_SIQ', data=df_box_siq, orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Average SIQ')
sns.boxplot(x='boredom', y='SE', data=df_box_siq, orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Self-Efficacy')
sns.boxplot(x='boredom', y='IN', data=df_box_siq, orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Interest')

sns.boxplot(x='boredom', y='CG', data=df_box_siq, orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Goals')
sns.boxplot(x='boredom', y='CA', data=df_box_siq, orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Action')
sns.boxplot(x='boredom', y='OE', data=df_box_siq, orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Catgeory: Outcome Expectation')
# Out:
# [Text(0.5, 1.0, 'SIQ Catgeory: Outcome Expectation')]

# %%
#Compare SIQ of bored and not bored - male vs female

os.chdir("C:\Maricel Files\PhD Journey\WHIMC")
df_box_siq=pd.read_csv("gender_analysis_all_SIQ_fb.csv")

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 12))

sns.boxplot(x='gender', y='Ave_SIQ', data=df_box_siq, hue='boredom', orient='v' , ax=axes[0][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='Average SIQ')
sns.boxplot(x='gender', y='SE', data=df_box_siq, hue='boredom', orient='v' , ax=axes[0][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Self-Efficacy')
sns.boxplot(x='gender', y='IN', data=df_box_siq, hue='boredom', orient='v' , ax=axes[0][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Interest')
sns.boxplot(x='gender', y='CG', data=df_box_siq, hue='boredom', orient='v' , ax=axes[1][0], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Goals')
sns.boxplot(x='gender', y='CA', data=df_box_siq, hue='boredom', orient='v' , ax=axes[1][1], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Category: Choice Action')
sns.boxplot(x='gender', y='OE', data=df_box_siq, hue='boredom', orient='v' , ax=axes[1][2], showmeans=True, meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}).set(title='SIQ Catgeory: Outcome Expectation')
# Out:
# [Text(0.5, 1.0, 'SIQ Catgeory: Outcome Expectation')]

# %% [markdown]
# #
